# %% [markdown]
# プログラミングを学習する中で最低限のパソコン周辺の知識が身に付く情報
# --------------------------------------------
# --------------------------------------------
# はじめに
# --------------------------------------------
# どうもはるぱぱです。
#
# 今回は私を含め、パソコンに触れる目的がプログラミング学習であったりするあなたが、プログラミングの学習を挫折しないためにどのような情報が必要なのか、ということについて考え、実際に私がこれまで挫折してきた経験をもとに、これだけの材料とプロセスがあればおよそ問題なくプログラミング学習を挫折することなく学習できるのではないか、というオールインワンのパッケージとして提供するためにこのコンテンツを作成いたしました。ぜひお役立ていただきたいと思います。
#
# さて、それでなくてもプログラミングだけで頭が痛いのに、周辺情報なんて、というかたのために、一旦次のスライドをご覧いただきたいと思います。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-03%2014.25.32.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-03%2014.25.32.png)
#
# まずはあなたがプログラミングを学習する先の話からです。
#
# あなたが個人のWeb作成としてプログラミングを学習するのであれば、おそらくHTMLやCSSを学習することになりますが、これらの学習を終えて実際の案件を頂くにしても、未経験でもできる案件の頻度は極端に少ないでしょう。
#
# そんな簡単にできるのであれば、忙しくて猫の手も借りたい、という企業でなければ、自分でやってしまえるのであればやってしまおう、というところの方が多いと思われるからです。
#
# また、プログラミングというとコーディングができればなんでもできる、というような考えで発信されている方も少なくありませんし、実際にコーディングをできる段階になって気付くこととして、統合開発環境のツールの操作方法だけでも、頭が痛いことになるのは今まで幾度となく挫折してきた方であれば想像にたやすいと思います。
#
# 中には環境構築でつまずいてコーディングすらできていない人もいるはずです。
#
# とすると、コーディング以前に環境構築の問題を解決する必要がありますし、その次に、さまざまな開発環境に適合するための根本的な構造を理解して、最低限のことで最大限のことができる、というあなたになる必要があります。
#
# もしこれを行わなかった場合、仮に今使っている、あるいは使おうとしている開発環境に新しいバージョンが搭載され、ユーザーインタフェースが大幅に変更された場合、あなたはまたいちからその操作方法について学んでいく必要があります。
#
# これではコーディングを覚えている最中にまた別の学習が挟まることで、体系的な学習になっていかないことが想像できることでしょう。
#
# 図にあるように、あなたがもし会社の企業案件を手広くこなすためにはプログラミング自体はごく一部の情報に過ぎないことを理解する必要があります。
#
# 膨大な情報を全て頭の中に入れてから案件を開始するというのは、先ほど申し上げたように変更される情報を含めて完全に理解するまでに相当な時間を要します。
#
# 場合によっては無理難題なこともあるでしょう。
#
# そう考えるとプログラミングのコーディングは通過地点でしかありません。
#
# あなたがもっとしておかなければならないことは、プログラミング学習で挫折しないためにどのような情報が必要なのか、という全体的な構造について知っておく必要があります。
#
# それはお手元にあるパソコン内部の話から始まって、プログラミングでできること、どんなものを作るときにどんな環境が必要で、その環境を利用するためにどのようなコーディングをしなければならない、といったことであったり、外部からどのようなパッケージを利用すれば目的を達成できるのか、ということです。
#
# つまり、膨大な情報を頭に入れない分、どのように調べて自分のスキルとして活用できるのか、というところが重要になってきます。
#
# それであっても、最低限の情報は頭に入れておかなければ、それを調べながらポチポチとボタンを押していては納期のある仕事としては成り立ちません。
#
# 学習する前提が個人の趣味や誰かの手助けでない以上、そうしたビジョンがある中で、できるだけ最速で学習されるのが望ましいと言えます。
#
# しかし、多くの場合、スクールに通ってお金を出せばそれらの全てを教えてくれると勘違いしている人も少なくありません。
#
# それはいわゆる独学の壁を楽に超えるレベル、という範囲であり、業務として必要な知識が広範囲にわたって身に付く、というものでないことを理解しておく必要があります。
#
# 実際にエンジニアからすれば、そうした問題解決能力が自分にあるかどうかで成長や持続の差にもつながると言われていますし、他力本願ではそこから伸び悩むことは目に見えています。
#
# とはいえ、まずはみなさまはそのスタートラインにすら立てていないということで今回のコンテンツを作成することになっていますので、最低限の情報を共有して、後の学習に速やかに移行できる、といったところを目指す情報でありたいと思っています。
#
# どうぞ最後までお付き合いいただけますようよろしくお願い申し上げます。

# %% [markdown]
# プログラミングを取り巻く情報については先ほどの図である程度大まかに示しましたが、プログラミングそのものについてはまだHTMLとCSSしかでてきていませんので、この辺りの関係性も目的に沿ったものであるかどうかを含めてお考えいただきたいと思います。
#
# 次のスライドをご覧ください。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-03%2014.10.41.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-03%2014.10.41.png)
#
# これは昨今よくつかわれるプログラミング言語と基本となるプログラミング言語の利用目的と関係について示しています。
#
# あなたが何かを作成したいと決まっている場合にはその言語を直接学習することも否めませんが、その言語の習得レベルがいきなり高いものではおそらく挫折につながります。
#
# 一見すると他の言語の中にも習得レベルの低いものもありますので、そちらをある程度理解して対応する箇所を本来学習する言語に置き換える、といったように学習をしていくことをお勧めします。
#
# 無駄な言語まで学習する必要があるのか、という声も聞こえてきそうではありますが、挫折しないためにどうするか、という点が重要ですので、こうしたプロセスを踏みながら、自分に足りない情報は何か、を知るためにも満遍なく学習しておく方が後々の学習を容易にします。
#
# 楽しさをモチベーションにしたい方はC#、サンプルや汎用性の高い言語で実務に活かしたい方はPython、といったようにチョイスされることもあるでしょう。
#
# またそれぞれの学習期間については、これらの全てを休日の丸一日学習できる環境で、いちから順番に習得した際に、サンプルコンテンツを利用して学習するとどのくらいで最低限の習得ができるのか、についておよそ算出されたものですので、仕事をしながら１日に数十分から数時間というような学習ペースでは適合しないことは申し上げておきます。
#
# また情報の切り口として、図で示すために本来の解釈から若干ズレていることもご容赦ください。
#
# このスライドの順番で学習を進める理由として、C言語は機械語に近く、人間の言葉として理解しづらいこと、C#はゲームやミニタスクなどを自身で作れるようになることで、実際の創作物が手軽に積み上げられること、Objective-CやSwiftはObjective-Cを中心に、Swiftとはアプリとして同じ物を作れる可能性が高く、Swift学習も用意になること、同時にC言語の上位互換として拡張されているため、C言語そのものがわからなくてもコンパイルでほぼ問題がないこと、Pythonはライブラリの多さとサンプルの多さで、実際に動かせば難しい本を読むより明らかに理解しやすいこと、Javaはアプリ開発ができるレベルであれば、翻訳する感じで習得できてしまうこと、JavaScriptはHTMLやCSSからいきなり学ぶより、こうした下積みがあって安全なプログラムを作れる土台があるかどうかで創作物の質が変わってくることなどが挙げられます。
#
# もちろん以前に学習した方はそうでなければならないことはありませんし、わかるところが増えたらご自身の目指すプログラミング言語を選択する事が重要ではないでしょうか。
#
# このようにプログラミング周辺とプログラミング言語の関係をみるだけでも結構な選択肢の分岐になってきます。
#
# 創作物を作れるか、作れないかでいえば、作れるというのはカンニングしながらでも作れれば問題ない、というところが最初の話ではありますが、実際にはWebで検索しても、専門用語が飛び交って意味のわからない世界に飛び込んでいる感じが否めないでしょう。
#
# 専門用語はそのときにぱっと見てぱっと理解する、というものではなく、見たり使いながら中身を理解する、という感覚でいる方が、毎回調べながら間違いのない情報を扱う癖がつきます。
#
# そのためにも「覚える」のではなく「慣れる」ことに重点を置きましょう。
#
# 意味を調べるだけならさほど時間をとりません。これだけでも大幅な学習時間の削減になります。

# %% [markdown]
# ここまで共有できたところで先ほど少し触れた、ユーザインターフェースの改変による再学習のリスクについてお考えいただきたいと思います。
#
# 今までパソコンを何台か買い換えた、あるいは何種類か購入して使ってきた、という人はそれぞれのOSの違いとバージョンの違いによって操作や構造が変わる、ということはわかるはずです。
#
# それがわかっているのであれば、この先また新たにそれらを学習する手間についても考えましょう。
#
# そう考えていくと、できることであれば少ない学習内容でできるだけ多くのことができる、という価値について気づくはずです。
#
# それを気づかせてくれるのがWindowsであればコマンドプロンプト、Macであればターミナル、LinuxであればLinuxコマンドといったコマンドレベルの命令です。
#
# これらはパソコンそのものにあるカーネルと呼ばれるプログラムに命令を直接送るコマンドになります。
#
# そしてそれらの多くは長年同じ命令で操作ができるように保持されています。
#
# つまり再学習するリスクが非常に少ないのです。
#
# 中にはマウスやキーボードといったGUIを使えば簡単にファイルやフォルダが作れる、という人もいますが、実際のファイル操作の中に隠しファイルなどがあってそれらを中身の編集で使う際に、GUIの操作では制限されているものもあります。
#
# ここででてきたGUIとCUIについてはご自身で早速Web検索してみましょう。
#
# 呼び方や知識として知っていなくても、調べながらどこの付近の情報の話をしているのか、という情報マッピングによりおよそ理解し慣れていくはずです。
#
# ここで重要なのは、めんどくさいコマンド命令を覚えるのではなく、それを使うことでどんなメリットがあるのか、についての必要性を感じることです。
#
# なくても困らない、というのはなくて困ったときに後悔する可能性が十分ある、ということです。
#
# マラソンで言うのであれば、給水地点で水を飲まなくても死なない、と言うのにゴール手前でバテてリタイアする人の話になります。
#
# プログラミングの話の中にもありましたが、コンパイルと言う翻訳ひとつにしても、IDEに頼りっきりで、デバイスやUIが変わった途端開発効率が著しく低下する、といったこともなきにしもあらずです。
#
# そう言う意味では、テキストベースであったり、コマンドレベルでいろんなことができるというのは、それらの問題を回避することにもなります。
#
# 石橋を叩く暇があったら、石橋を３つほど作ってどれを渡っていいかチョイスできる状態にしましょう。
#
# 1つでつまずけばそれは挫折につながります。
#
# そしてコマンドは最低限、ファイルやフォルダの作り方(mkdir や touch)、見方(ls や　ls -a)、変更や移動の仕方(mv や オプション-r -fなど)、削除の仕方(rm)が分かればとりあえずは最初の段階では十分です。
#
# これをWindowsとMacの2つで使いこなせればいいだけです。
#
# これらの操作方法もWebで検索すればでてきます。文章を読むというより実際にコマンドを入力してどのように動くか、そして動かない場合はどうしたら動くのか、という構造や意味について考えるところから始めましょう。
#
# その考え方がプログラミングの中で物事を結果から逆算して仮定に基づいて修正する、といったようなプロセスとして非常に役立ってきます。
#
# イメージで言えばデザインを絡めた構築になるでしょうし、計算で言えば左辺に結果の数字、右辺には計算させる計算方法と言うことになり、これらをプロセスとして導くための土台となります。
#
# ここでプログラミング初学者としてはあれ？計算って左辺が計算式で右辺が答えじゃないの？となると思います。
#
# 1 + 1 = 2　これが算数の計算式です。
#
# プログラミングではこれを変数という値を使って代入します。
#
# int a = 0;  //整数(int)型の　a という変数に　０　を代入する
#
# a = 1 + 1; //1 + 1 の結果を a に代入する
#
# これがプログラミングの計算式です。
#
# // という記号が出てきましたがこれはコメントアウトです。言語によっては # をつかったり　" " や ' ' を使うものもあります。
#
# HTMLの場合は半角の ＜！ーー この間 ーー＞ がコメント文として認識されます。（実際に半角でこちらに記入すると<!-- この部分が見えません -->←みえなくなりますので、視認するために全角で記入してあります。みたい場合はダブルクリックでテキスト内をご確認ください。)
#
# ちなみに a　という中身を表示させるときには
#
# C言語では　printf("%d", a);
#
# C#では  Console.WriteLine(a);
#
# Objective-Cでは NSLog("%d", a);
#
# Javaでは System.out.printf(a);
#
# のように予約語を使います。
#
# 正確な表記になっているかは情報リテラシーの観点からもご自身でご確認ください。
#
# ご覧のように言語によっては同じつづりになる部分もありますのでイメージは掴みやすくなります。
#
# このように使用される予約語やルール、あるいは型について理解することがプログラミング言語を理解する早道です。
#
# コマンドを理解するとファイル操作ができるようになりますが、そのファイルを管理することが必要になってくる場合があります。
#
# それを個人のテキストに年月日や時間、コメントなど含めて詳細を書くとそれだけでかなりの手間となってしまいます。
#
# 何より作成途中のファイルを消去してしまった、前の修正まで戻したい、といったような事態に対応できません。
#
# そこで必要になるのがファイルのバージョン管理ができるGitというものです。
#
# とはいえ、このGItですが説明がされている本やWeb検索でも理解しづらいものも多く、要点が絞り込まれていないものがほとんどでかえって混乱を招きます。
#
# 必要な情報はGithub内に以下のフォルダに端的にまとめてあります。
#
# ダウンロードしてご利用ください。
#
# またこのファイルには.ipynbという拡張子のファイルが含まれますので、Anacondaというアプリケーション管理ツールまたはGoogleColaboratory(画像が観れるのはAnacondaのjupyternotebookだけです)で読み込んでご利用いただくことになります。
#
# いずれにしてもこれらのツールは開発途中で必要になってくるはずです。
#
# https://github.com/harupapa-git001/Github
#
# GoogleColaboratoryで画像が見れない人のためにスライドをこちらに貼り付けておきます。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2014.29.39.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2014.29.39.png)
#
# 最低限抑えておきたいところだけの情報ですので、ご自身で掘り下げたい方は各書籍などをご覧ください。
#
# とりあえずここまで一通りを学習したらプログラミングから開発までの最低限の土台はできていると言えます。

# %% [markdown]
# たったこれだけの学習のあるなしで今後の挫折に大きく影響してくると考えると大変気が楽になったのではないでしょうか。
#
# そしていよいよプログラミング言語に触れていきます。
#
# 下記のスライドはObjective-Cのものです。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2010.06.41.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2010.06.41.png)
#
# 実際のプログラムはテキストベースで書いてコマンドでコンパイルするといった流れになりますが、ここではそうした環境が手間だと言うときに、WebブラウザでコンパイルできるPaiza　Cloudをご紹介しておきます。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2017.25.23.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2017.25.23.png)
#
# 多言語対応ですので是非サンプルコードなどを打ち込んで使えるかを試してみてください。
#
# 本解説ではテキストベースでの解説となりますのでそちらで習得されることをお勧めします。
#
# まず最初に気をつけておきたいのが、書き方は人それぞれで決まった書き方と言うものが大まかにしかありません。
#
# そうした中で重要になってくるのが型です。
#
# ![%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2017.30.29.png](attachment:%E3%82%B9%E3%82%AF%E3%83%AA%E3%83%BC%E3%83%B3%E3%82%B7%E3%83%A7%E3%83%83%E3%83%88%202020-07-05%2017.30.29.png)
#
# これは先ほどご覧になったObjective-CのPaiza Cloudのデフォルトのものですが、非常に難しくなっているように感じないでしょうか？
#
# 一文の中に長い文字列が詰め込まれると、初学者としては萎える原因になりますので、こうした書き換えに関しては今後の学習の中で徐々に修正されていくことが望ましいと言えます。
#
# また、コンパイルでエラーがなく動くプログラムでも、実はセキュリティに脆弱であったり、データの扱いが不適切であるなどといった問題も発生してきます。
#
# 入門書などの著書ではなく、Webでのブログや解説を写して実行する「写経」をする際には充分ご注意ください。
#
# この点に注意した上で、C#とPythonとObjective-Cのサンプルを下記からダウンロードして、型を覚えるついでに、実際にサンプルコードを動かしてから１文ずつ解読するために本などを読み進めましょう。
#
# https://github.com/harupapa-git001/C-
#
# https://github.com/harupapa-git001/Python
#
# https://github.com/harupapa-git001/Objective-C
#
# ここで重要なのが、動くサンプルを手元に置いておく、ということです。
#
# 初学者はどれが正解といった判断ができません。
#
# また、正解のコードを書き写すにしても、間違った文字や型を入力してしまい、自分でエラーを作り出す割合が非常に多いのも特徴です。
#
# まずは短い文を書き写しながら、間違いのない型をかけるようになることで、その他の文のどこかに間違いがある可能性として絞り込めます。
#
# 当然エラーがあるときはエラー文を読めば、およそのエラーが発生した位置がわかるようになっていますが、細かな修正は自分で行うことになるので、思い込みなどによる間違いの認識不足が発生しないようにしましょう。
#
# 時代の違う本などでサンプルコードを入力している時は、誤植などによってエラーが出ている時もありますが、基本的にサンプルコードとして保存しているファイルはREADME.txtなどに記載している場合以外は全て動く前提で動作確認済みです。
#
# 動く結果が見えれば、どこがどう間違っているのか見当がつけやすく、挫折しにくいといった特徴があります。
#
# また、忘れないうちに、ダウンロードしたファイルはGItなどにプッシュして保存しておくことをお勧めします。
#
# Git操作に慣れている人はクローンで更新する形でも良いでしょう。
#
# 本解説で提供するもの以外ではiPadをお持ちの方であればSwift PlaygroundというゲームアプリでSwiftを学べますし、JavaやJavaScript、HTMLやCSSといったものはprogateという学習サイトでも学べます。
#
# 習うより慣れろ、とよく言われるプログラミング学習ですが、サンプルコードをどんどん書いているうちに気になってくるところがあるはずですので、その部分を書き留めておいて一旦全て終えたときに最初から中身がどうなっているのかについて学習を始めると、気になった点がはっきりしてくる、と言う感じで、ただ漠然と文章を読んで理解しているよりはるかにピンポイントで明確なイメージとしてつながってくるはずです。
#
# ひと通り理解した後で、数十程度の例題を実際に自分で出力結果から考えながら作成し、わからないところだけ修正すると、恐らくさほどの時間を要することなく実際に自分で作ったと言えるプログラムが出来上がります。
#
# この繰り返しをしていく中で、徐々に自分でかける部分が増えて定着する、と言う流れがプログラミング学習のプロセスで重要なポイントだと言えます。
#
# そこまでできてしまうと、みなさんの目指す創作物はもう目の前にあるといっても過言ではないでしょう。
#
# なんとなく学習イメージが掴めたなら是非今から学習してみてください。
#
# そしてたったこれだけの情報があるだけで実際に挫折しなかったご自身が居たときに、最低限の情報を共有することの重要性について改めてお考えいただければ幸いです。
